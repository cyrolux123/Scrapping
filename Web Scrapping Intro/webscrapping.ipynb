# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import logging

# %%
flipcart_url = "https://www.flipkart.com/search?q=" + "iphone14"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone14'

# %%
urlclient = urlopen(flipcart_url)

# %%
urlclient

# %%
flipcart_page = urlclient.read()

# %%
flipcart_html = bs(flipcart_page,'html.parser')

# %%
"https://www.flipkart.com/"+"apple-iphone-14-midnight-128-gb/p/itm9e6293c322a84?pid=MOBGHWFHECFVMDCX&lid=LSTMOBGHWFHECFVMDCXXRTRJG&marketplace=FLIPKART&q=iphone+14&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_ps&fm=search-autosuggest&iid=9a91056a-387b-47e6-8dc9-767d9af485fe.MOBGHWFHECFVMDCX.SEARCH&ppt=sp&ppn=sp&ssid=ffwz7h737k0000001706940727277&qH=860f3715b8db08cd"
# Out:
# 'https://www.flipkart.com/apple-iphone-14-midnight-128-gb/p/itm9e6293c322a84?pid=MOBGHWFHECFVMDCX&lid=LSTMOBGHWFHECFVMDCXXRTRJG&marketplace=FLIPKART&q=iphone+14&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_ps&fm=search-autosuggest&iid=9a91056a-387b-47e6-8dc9-767d9af485fe.MOBGHWFHECFVMDCX.SEARCH&ppt=sp&ppn=sp&ssid=ffwz7h737k0000001706940727277&qH=860f3715b8db08cd'

# %%
bigbox = flipcart_html.findAll("div" ,{"class":"_1fQZEK"})

# %%
len(bigbox)

# %%
del bigbox[0:3]

# %%
productlink = "https://www.flipkart.com"+ bigbox[3].div.div.div.a['href']

# %%
product_req = requests.get(productlink)

# %%
productlink

# %%
product_html = bs(product_req.txt,'html.parser')

# %%
product_html.find_all("div",{"class" : "_16PBlm"})

# %%
len(comment_box)

# %%
for i in comment_box:
    print(i.div.div.find_all('p',{"class" : "_2sc7ZR _2V5EHH"})[0].text)

# %%
for i in comment_box:
    print(i.div.div.div.div.text)

# %%
comment_box[0].div.div.div.p.text

# %%
for i in comment_box:
    print(i.div.div.div.p.text)

# %%
comment_boc[0].div.div.find_all('div',{"class":''})[0].div.text

# %%
for i in bigbox:
    print("https://www.flipkart.com" + i.div.div.div.a['href'])
